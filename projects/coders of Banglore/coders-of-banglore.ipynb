# %%
import json

# %%
with open("initialdata.txt",'r',encoding='utf-8') as f:
    data = f.read()

# %%
chunks = data.split("\n\n")
chunks = [c for c in chunks if(len(c)>3)]

# %%
def parce_chuck(chunk):
    ch = chunk.strip()
    split_data = ch.split("\n")
    if(len(split_data) >=4):
        
        username = split_data[0]
        
        no_of_posts = int(split_data[1].split(" ")[0].replace(",",""))
        
        no_of_followers = float(split_data[2].split(" ")[0].replace(",","").replace("K","").replace("M",""))
        if("K" in split_data[2]):
            no_of_followers = int(no_of_followers*1000)
        elif("M" in split_data[2]):
            no_of_followers = int(no_of_followers*1000000)
        else:
            no_of_followers = int(no_of_followers)
            
        no_of_following = float(split_data[3].split(" ")[0].replace(",","").replace("K","").replace("M",""))
        if("K" in split_data[3]):
            no_of_following = int(no_of_following*1000)
        elif("M" in split_data[3]):
            no_of_following = int(no_of_following*1000000)
        else:
            no_of_following = int(no_of_following)
        
        name = split_data[4]
        if(len(split_data)>5):
            type_of_page = split_data[5]
            bio = "\n".join(split_data[6:])
        else:
            type_of_page = "Unknown"
            bio = ""
            
        return {
            "username" : username,
            "no_of_posts" : no_of_posts,
            "no_of_followers" : no_of_followers,
            "no_of_following" : no_of_following,
            "name" : name,
            "type_of_page" : type_of_page,
            "bio" : bio
        }
    return {
        "username": "",
        "no_of_posts": "",
        "no_of_followers": "",
        "no_of_following": "",
        "name": "",
        "type_of_page": "Unknown",
        "bio": ""
    }

# %%
all_chunks = []
for chunk in chunks:
    all_chunks.append(parce_chuck(chunk))
# all_chunks

# %%
import json
s = json.dumps(all_chunks, indent=4)
with open("initialdata.json", "w") as f:
    f.write(s)
# print(s)

# %% [markdown]
# #### Who has Maximum posts?

# %%
max_post = 0
for chunk in all_chunks:
    if(max_post<chunk['no_of_posts']):
        max_post = chunk['no_of_posts']
        max_post_chunk = chunk
print(max_post_chunk)
# Out:
# {'username': 'startuphub_blr', 'no_of_posts': 2300, 'no_of_followers': 45000, 'no_of_following': 120, 'name': 'Startup Hub Bangalore', 'type_of_page': 'Media', 'bio': '🦄 News from the Silicon Valley of India\n📢 Funding alerts, Hiring trends, and Drama\n📩 DM for features\nstartuphub.blr/newsletter'}

# %% [markdown]
# #### Who has Maximum followers?

# %%
max_followers = 0
for chunk in all_chunks:
    if(max_followers<chunk['no_of_followers']):
        max_followers = chunk['no_of_followers']
        max_followers_chunk = chunk
print(max_followers_chunk)
# Out:
# {'username': '_anujsinghal', 'no_of_posts': 1785, 'no_of_followers': 681000, 'no_of_following': 248, 'name': 'Anuj Singhal', 'type_of_page': 'Digital creator', 'bio': 'Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India\nLet’s talk about finance and life\nContact: Singhalanuj1010@gmail.com\nhindi.cnbctv18.com/market-gurukul'}

# %% [markdown]
# #### Who has Maximum following?

# %%
max_following = 0
for chunk in all_chunks:
    if(max_following < chunk['no_of_following']):
        max_following = chunk['no_of_following']
        max_following_chunk = chunk
print(max_following_chunk)
# Out:
# {'username': 'katiasales2220', 'no_of_posts': 107, 'no_of_followers': 219, 'no_of_following': 1401, 'name': 'Katia Sales', 'type_of_page': 'Alfabetização e Reforço Escolar', 'bio': 'Ensino Fundamental I e II\nPreparação para Escola Militar\nPortuguês e Matemática\nCursando Psicopedagogia Estácio'}

# %% [markdown]
# #### How many categories and How many people?

# %%
categories = []
for chunk in all_chunks:
    if(chunk['type_of_page'] in chunk):
        continue
    else:
        categories.append(chunk['type_of_page'])
print(categories)
print(len(categories))
print(len(all_chunks))
# Out:
# ['Nonprofit organization', 'Digital creator', 'Blogger', 'Entrepreneur', 'Public Figure', 'Media', 'Food & Drink', 'Investor', 'Community', 'Personal Blog', 'Gamer', 'Unknown', 'Alfabetização e Reforço Escolar']
# 13
# 13
