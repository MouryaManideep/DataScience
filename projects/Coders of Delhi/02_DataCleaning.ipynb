# %% [markdown]
# ## **Task 1: Identify Issues in the Data**
# Your manager provides you with an example dataset where some records are incomplete or incorrect. Here’s an example:
#
# ```json
# {
#     "users": [
#         {"id": 1, "name": "Amit", "friends": [2, 3], "liked_pages": [101]},
#         {"id": 2, "name": "Priya", "friends": [1, 4], "liked_pages": [102]},
#         {"id": 3, "name": "", "friends": [1], "liked_pages": [101, 103]},
#         {"id": 4, "name": "Sara", "friends": [2, 2], "liked_pages": [104]},
#         {"id": 5, "name": "Amit", "friends": [], "liked_pages": []},
#         {"id": 6, "name": "Raj", "friends": [], "liked_pages": [1]}
#     ],
#     "pages": [
#         {"id": 101, "name": "Python Developers"},
#         {"id": 102, "name": "Data Science Enthusiasts"},
#         {"id": 103, "name": "AI & ML Community"},
#         {"id": 104, "name": "Web Dev Hub"},
#         {"id": 104, "name": "Web Development"}
#     ]
# }
# ```
#
# **Problems:**
# 1. User **ID 3** has an empty name.
# 2. User **ID 4** has a duplicate friend entry.
# 3. User **ID 5** has no connections or liked pages (inactive user).
# 4. The **pages list** contains duplicate page IDs.

# %%
import json

# %%
def cleaned_data(data):

    # Remove empty name users and updating
    data['users'] = [user for user in data['users'] if user['name'].strip()]

    # Remove duplicate user friends and updating
    for user_f in data['users']:
        user_f['friends'] = list(set(user_f['friends']))

        # print(user_f['friends'], "-->")
        # if user_f['friends']:
        #     print(True)
        # else:
        #     print(False)

    # Remove user who has no connections or liked pages (inactive user)
    data['users'] = [user for user in data['users'] if user['friends'] or user['liked_pages']]

    # Remove duplicate page IDs and updating 
    unique_pages = {}
    for page in data['pages']:
        unique_pages[page['id']] = page
    data['pages'] = unique_pages
    
    return data

# Load the data
data = json.load(open("data2.json"))
# print(type(data))
data = cleaned_data(data)
json.dump(data, open('cleaned_data2.json', 'w'), indent=4)

# %% [raw]
# # The primary difference is that json.dump() writes a Python object to a file-like object, while json.dumps() returns the object as a JSON-formatted string. The "s" in dumps can be a mnemonic for "string".

# %%
# help(json.dump) 
# help(json.dumps)
